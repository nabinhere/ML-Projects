# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/Machine Learning projects/datasets/comparison.csv')

# %%
data.head()
# Out:
#     voltage1  current1        soc1  ...        soc2      temp2       soh2
# 0  12.512054  5.245053  100.000000  ...  100.000000  25.000000  100.00403
# 1  12.535906  3.105179  100.000000  ...  100.000000  25.000000  100.00403
# 2  12.498593  3.437299   99.955076  ...   99.955076  25.000000  100.00403
# 3  12.464902  3.223150   99.905346  ...   99.905346  25.000642  100.00403
# 4  12.408428  5.323233   99.858715  ...   99.858715  25.001014  100.00403
#
# [5 rows x 12 columns]

# %%
volt_diff, current_diff, soc_diff, temp_diff, soh_diff = data['voltage1'] - data['voltage2'],data['current1'] - data['current2'],data['soc1'] - data['soc2'],data['temp1'] - data['temp2'], data['soh1'] - data['soh2']

# %%
volt_diff.shape
# Out:
# (14401,)

# %%
 data.describe()
# Out:
#            voltage1      current1  ...         temp2          soh2
# count  14401.000000  14401.000000  ...  14401.000000  14401.000000
# mean      11.380294      0.036452  ...     25.043059     99.986973
# std        0.132287      3.949128  ...      0.008469      0.010552
# min       11.207641     -3.300000  ...     25.000000     99.969589
# 25%       11.299508     -3.300000  ...     25.041462     99.978779
# 50%       11.369976     -3.300000  ...     25.043999     99.987907
# 75%       11.375105      3.879858  ...     25.048048     99.997250
# max       12.535906     10.996608  ...     25.054526    100.004030
#
# [8 rows x 12 columns]

# %%
x = np.arange(14401)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.plot(x, volt_diff*100/10.8)
plt.show()

# %%
plt.plot(x, current_diff)
plt.show()

# %%
data.isnull().sum()
# Out:
# voltage1     0
# current1     0
# soc1         0
# temp1        0
# soh1         0
# nachaine1    0
# voltage2     0
# nachaine2    0
# current2     0
# soc2         0
# temp2        0
# soh2         0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
plt.subplot(321)
plt.plot(x, volt_diff)
plt.title('voltage difference')

plt.subplot(322)
plt.plot(x, current_diff)
plt.title('current difference')

plt.subplot(323)
plt.plot(x, soc_diff)
plt.title('soc difference')

plt.subplot(324)
plt.plot(x, temp_diff)
plt.title('temp difference')

plt.subplot(325)
plt.plot(x, soh_diff)
plt.title('soh difference')

plt.show()
