# %%
import pandas as pd
import numpy as np

# %%
electives = pd.read_csv('/content/electives.csv')

# %%
electives.head()
# Out:
#                                email  ...  Elective III - Wind Energy Conversion System
# 41    074bel301.aayam@pcampus.edu.np  ...                                           2.0
# 39  074bel302.abinash@pcampus.edu.np  ...                                           2.0
# 0   074bel303.adarsha@pcampus.edu.np  ...                                           2.0
# 8    074bel304.anjana@pcampus.edu.np  ...                                           3.0
# 13     074bel305.anup@pcampus.edu.np  ...                                           2.0
#
# [5 rows x 7 columns]

# %%
electives.shape
# Out:
# (52, 7)

# %%
electives = electives.sort_values(by=['email'])

# %%
electives
# Out:
#                                  email  ... Elective III - Wind Energy Conversion System
# 0       074bel301.aayam@pcampus.edu.np  ...                                            2
# 1     074bel302.abinash@pcampus.edu.np  ...                                            2
# 2     074bel303.adarsha@pcampus.edu.np  ...                                            2
# 3      074bel304.anjana@pcampus.edu.np  ...                                            3
# 4        074bel305.anup@pcampus.edu.np  ...                                            2
# 5       074bel306.arjun@pcampus.edu.np  ...                                            2
# 6       074bel306.arjun@pcampus.edu.np  ...                                            2
# 7    074bel307.bimarsha@pcampus.edu.np  ...                                          NaN
# 8      074bel308.bishal@pcampus.edu.np  ...                                            2
# ...

# %%
niruja = pd.DataFrame(np.array([['074bel326.niruja@pcampus.edu.np',3,2,1,2,3,1]]), columns = ['email', 'Elective II - Advanced Power System',	'Elective II - Biomedical Engineering',	'Elective II - Applied Photovoltaic',	'Elective III - Artificial Neural Network',	'Elective III - Micro-Hydro Power',	'Elective III - Wind Energy Conversion System'])

# %%
electives = electives.append(niruja, ignore_index=True)

# %%
# electives.drop(3, axis = 0)

# %%
# electives

# %%
electives.loc[[16]]
# Out:
#                               email  ... Elective III - Wind Energy Conversion System
# 16  074bel314.ganesh@pcampus.edu.np  ...                                            1
#
# [1 rows x 7 columns]

# %%
electives.loc[[16],'Elective III - Wind Energy Conversion System'] = 1
electives.loc[[16],'Elective III - Artificial Neural Network'] = 2

# %%
electives.to_csv('modified electives.csv')

# %%
electives
# Out:
#                                  email  ... Elective III - Wind Energy Conversion System
# 0       074bel301.aayam@pcampus.edu.np  ...                                            2
# 1     074bel302.abinash@pcampus.edu.np  ...                                            2
# 2     074bel303.adarsha@pcampus.edu.np  ...                                            2
# 3      074bel304.anjana@pcampus.edu.np  ...                                            3
# 4        074bel305.anup@pcampus.edu.np  ...                                            2
# 5       074bel306.arjun@pcampus.edu.np  ...                                            2
# 6       074bel306.arjun@pcampus.edu.np  ...                                            2
# 7    074bel307.bimarsha@pcampus.edu.np  ...                                          NaN
# 8      074bel308.bishal@pcampus.edu.np  ...                                            2
# ...
